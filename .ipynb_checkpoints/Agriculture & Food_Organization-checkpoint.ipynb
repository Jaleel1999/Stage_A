# %%
import pandas as pd

# %%
dataframe = pd.read_csv('FoodBalance.csv' , encoding = 'latin-1')

# %%
print(dataframe)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Highest and lowset for the year 2017
sorted(dataframe.groupby('Area')['Y2017'].sum())
# Out:
# [0.0,
#  0.0,
#  59.839999999999996,
#  442.34000000000003,
#  12662.630000000001,
#  14650.74,
#  19102.77,
#  21267.96,
#  22101.3,
#  22729.91,
#  23154.18,
#  27979.64,
#  29342.2,
#  29874.89,
#  29937.0,
#  41181.68,
#  49841.88,
#  51114.83,
#  54343.33,
#  55311.33,
#  71594.68,
#  73663.69,
#  75919.34,
#  95681.15,
#  98138.87,
#  101855.06999999999,
#  103223.77,
#  124167.2,
#  124771.22,
#  126707.58,
#  131197.73,
#  149928.33,
#  156665.46,
#  161407.98,
#  181098.71,
#  213950.38,
#  224599.01,
#  229159.57,
#  232030.43,
#  239931.92,
#  264660.66,
#  322616.85,
#  325644.27,
#  337599.06,
#  388495.36,
#  448683.76,
#  517590.54,
#  866379.92,
#  1483268.23]

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Total number of of missing data in the year 2014
dataframe['Y2014'].isnull().sum()
# Out:
# 1589

# %%
# total Protein supply qunatity in Madagascar in 2015.
dataframe['Y2015'].loc[(dataframe['Area']=='Madagascar') & (dataframe['Element']=='Protein supply quantity (g/capita/day)')].sum()
# Out:
# 173.04999999999998

# %%
import numpy as np

array  = np.array([[94, 89, 63],

                   [93, 92, 48],

                   [92, 94, 56]])
array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
#Total sum of wine produced in 2015 and 2018.
dataframe[['Y2015','Y2018']].loc[(dataframe['Item'] == 'Wine')].sum()
# Out:
# Y2015    4251.81
# Y2018    4039.32
# dtype: float64

# %%
# Mean and standard deviation across the year 2017
dataframe['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
# highest sum of stock Variation.

m = dataframe.groupby(['Element'])
m.first()
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
#which year had the least correlation with Element Code. 
m = dataframe.groupby(['Element Code'])
m.max()
# Out:
#               Area Code                   Area  Item Code        Item  \
# Element Code
# 511                 276               Zimbabwe       2501  Population
# 645                 276               Zimbabwe       2961        Yams
# 664                 276               Zimbabwe       2961        Yams
# 674                 276               Zimbabwe       2961        Yams
# 684                 276               Zimbabwe       2961        Yams
# 5072                276               Zimbabwe       2961        Yams
# 5123                276               Zimbabwe       2949        Yams
# 5131                276               Zimbabwe       2948        Wine
# 5142                276               Zimbabwe       2961        Yams
# 5154                276               Zimbabwe       2961        Yams
# 5170                276               Zimbabwe       2949        Yams
# 5171                193  Sao Tome and Principe       2949        Yams
# ...
